# %%
alien_0 = {'color':'green','points':5}
print(alien_0['color'])
print(alien_0['points'])
# Out:
# green
# 5

# %%
alien_0['x_position'] = 0
alien_0['y_position'] = 25
print(alien_0)
# Out:
# {'color': 'green', 'points': 5, 'x_position': 0, 'y_position': 25}

# %%
Starting with an empty dictionaries

# %%
alien_1 = { }
alien_1['color'] = 'red'
alien_1['points'] = 5
print(alien_1)
# Out:
# {'color': 'red', 'points': 5}

# %%
Modify value in a dictionary

# %%
alien_1 = {'color':'green'}
print(f"The alien is {alien_1['color']}.")

alien_1['color'] =  'red'
print(f"The alien is now {alien_1['color']}.")
# Out:
# The alien is green.
# The alien is red.

# %%
alien_0['x_position'] = 0
alien_0['y_position'] = 25
alien_0['speed'] = 'medium'
print(alien_0)
print(f"The original position of alien is {alien_0['x_position']}")

if alien_0['speed'] == 'slow':
    x_increment = 1
elif alien_0['speed'] == 'medium':
    x_increment = 2
else:
    x_increment = 3
    
alien_0['x_position'] = alien_0['x_position'] + x_increment
print(f"The new position of alien is {alien_0['x_position']}")
# Out:
# {'color': 'red', 'x_position': 0, 'y_position': 25, 'speed': 'medium'}
# The original position of alien is 0
# The new position of alien is 2

# %%
Removing key value pairs

# %%
alien_2 = { }
alien_2['color'] = 'yellow'
alien_2['points'] = 5
print(alien_2)

del alien_2['points'] 
print(alien_2)
# Out:
# {'color': 'yellow', 'points': 5}
# {'color': 'yellow'}

# %%
A Dictionary of Similar objects

# %%
favorite_languages = {
    'jen':'python',
     'sarah':'c',
    'edward':'ruby',
    'phil':'python'
}
print(favorite_languages)

language = favorite_languages['sarah'].title()
print(f"Sarah's Favorites language is {language}.")
# Out:
# {'jen': 'python', 'sarah': 'c', 'edward': 'ruby', 'phil': 'python'}
# Sarah Favorites language is C.

# %%
Using get to access values

# %%
favorite_languages.get('points')

# %%
 6-1. Person: Use a dictionary to store information about a person you know . 
Store their first name, last name, age, and the city in which they live . You 
should have keys such as first_name, last_name, age, and city . Print each 
piece of information stored in your dictionary

# %%
person = {'first_name':'Ajay','last_name':'Kumar','age':33,'city':'Amelia'}
print(person['first_name'])
print(person['last_name'])
print(person['age'])
print(person['city'])
# Out:
# Ajay
# Kumar
# 33
# Amelia

# %%
 6-2. Favorite Numbers: Use a dictionary to store people’s favorite numbers . 
Think of five names, and use them as keys in your dictionary . Think of a favorite 
number for each person, and store each as a value in your dictionary . Print 
each person’s name and their favorite number . For even more fun, poll a few 
friends and get some actual data for your program

# %%
favorite_number = {'Nancy':9,'Neha':8,'Aarvi':4,'Ajay':3}
print(f"Nancy's favorite number is:{favorite_number['Nancy']}")
print(f"Neha's favorite number is:{favorite_number['Neha']}")
print(f"Aarvi's favorite number is:{favorite_number['Aarvi']}")
print(f"Ajay's favorite number is:{favorite_number['Ajay']}")
# Out:
# Nancy's favorite number is:9
# Neha's favorite number is:8
# Aarvi's favorite number is:4
# Ajay's favorite number is:3

# %%
Looping through All key value pairs

# %%
user_0 = {
    'username':'Ajayacme',
    'first':'Ajay',
    'last':'kumar',
    
}
print(user_0)
# Out:
# {'username': 'Ajayacme', 'first': 'Ajay', 'last': 'kumar'}

# %%
for key,value in user_0.items():
    print(f"\nKey: {key}")
    print(f"Value: {value}")
# Out:
# Key: username
# Value: Ajayacme
#
# Key: first
# Value: Ajay
#
# Key: last
# Value: kumar

# %%
favorite_languages = {
    'jen':'python',
     'sarah':'c',
    'edward':'ruby',
    'phil':'python'
}
print(favorite_languages)
for name,language in favorite_languages.items():
    print(f"{name.title()}'s favorite language is:{language}")
# Out:
# {'jen': 'python', 'sarah': 'c', 'edward': 'ruby', 'phil': 'python'}
# Jen's favorite language is:python
# Sarah's favorite language is:c
# Edward's favorite language is:ruby
# Phil's favorite language is:python

# %%
Looping through All keys

# %%
favorite_languages = {
    'jen':'python',
     'sarah':'c',
    'edward':'ruby',
    'phil':'python'
}
for name in favorite_languages.keys():
    print(name.title())
# Out:
# Jen
# Sarah
# Edward
# Phil

# %%
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
    }

friends = ['phil', 'sarah']
for name in favorite_languages.keys():
    print(f"Hi {name.title()}.")
    
    if name in friends:
        language = favorite_languages[name].title()
        print(f"\t{name.title()}, I see you love {language}!")
# Out:
# Hi Jen.
# Hi Sarah.
# 	Sarah, I see you love C!
# Hi Edward.
# Hi Phil.
# 	Phil, I see you love Python!

# %%
friends = ['phil', 'sarah']
#for name in favorite_languages.keys():
print(name.title())
    
if name in friends:
        language = favorite_languages[name].title()
        print(f"\t{name.title()}, I see you love {language}!")
# Out:
# Phil
# 	Phil, I see you love Python!

# %%
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
    }
for name in favorite_languages.keys():
    print(f"{name.title()},thank you for taking the poll.")
# Out:
# Jen,thank you for taking the poll.
# Sarah,thank you for taking the poll.
# Edward,thank you for taking the poll.
# Phil,thank you for taking the poll.

# %%
loop through keys in a particular order

# %%
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
    }
for name in sorted(favorite_languages.keys()):
    print(f"{name.title()},thank you for taking the poll.")
# Out:
# Edward,thank you for taking the poll.
# Jen,thank you for taking the poll.
# Phil,thank you for taking the poll.
# Sarah,thank you for taking the poll.

# %%
loop through all values in a dictionary

# %%
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
    }
print("The Following Langauges have been mentioned:")
for language in favorite_languages.values():
    print(language.title())
# Out:
# The Following Langauges have been mentioned:
# Python
# C
# Ruby
# Python

# %%
remove reptition

# %%
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
    }
print("The Following Langauges have been mentioned:")
for language in set(favorite_languages.values()):
    print(language.title())
# Out:
# The Following Langauges have been mentioned:
# Ruby
# Python
# C

# %%
set

# %%
languages = {'python','ruby','python','c'}
print(languages)
# Out:
# {'ruby', 'python', 'c'}

# %%
Nesting

# %%
# Make an empty list for storing aliens.
aliens = []

# Make 30 green aliens.
for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

for alien in aliens[:3]:
    if alien['color'] == 'green':
        alien['color'] = 'yellow'
        alien['speed'] = 'medium'
        alien['points'] = 10
    
# Show the first 5 aliens.
for alien in aliens[:5]:
    print(alien)
print("...")

# %%
# Make an empty list for storing aliens.
aliens = []

# Make 30 green aliens.
for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)
    
for alien in aliens[:5]:
    print(alien)
print("...")

print(f"Total number of aliens:{len(aliens)}")


    
#print(aliens)
# Out:
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# ...
# Total number of aliens:30

# %%
for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)
    
for alien`in aliens[0:3]:
      if alien['color'] == 'green':
        alien['color'] = 'Yellow'
        alien['speed'] = 'medium'
        alien['points'] = 10
        
print(aliens)
# Out:
#   Cell In[58], line 5
#     for alien`in aliens[:3]:
#              ^
# SyntaxError: invalid syntax

# %%
A list in a Dictionary

# %%
 # Store information about a pizza being ordered.
pizza = {
    'crust': 'thick',
    'toppings': ['mushrooms', 'extra cheese'],
    }

# Summarize the order.
print(f"You ordered a {pizza['crust']}-crust pizza "
    "with the following toppings:")

for topping in pizza['toppings']:
    print("\t" + topping)
# Out:
# You ordered a thick-crust pizza with the following toppings:
# 	mushrooms
# 	extra cheese

# %%
favorite_languages = {
    'jen': ['python','Java'],
    'sarah': ['c'],
    'edward': ['ruby','C++'],
    'phil': ['python','sql']
    }
#print("The Following Langauges have been mentioned:")
for name,languages in favorite_languages.items():
    print(f"{name.title()}'s favorite langauges are:")
    for language in languages:
        print(f"\t{language.title()}")
# Out:
# Jen's favorite langauges are:
# 	Python
# 	Java
# Sarah's favorite langauges are:
# 	C
# Edward's favorite langauges are:
# 	Ruby
# 	C++
# Phil's favorite langauges are:
# 	Python
# 	Sql

# %%
users = {
    'aeinstein': {
        'first': 'albert',
        'last': 'einstein',
        'location': 'princeton',
        },

    'mcurie': {
        'first': 'marie',
        'last': 'curie',
        'location': 'paris',
        },

    }

for username, user_info in users.items():
    print(f"\nUsername: {username}")
    full_name = f"{user_info['first']} {user_info['last']}"
    location = user_info['location']

    print(f"\tFull name: {full_name.title()}")
    print(f"\tLocation: {location.title()}")
# Out:
# Username: aeinstein
# 	Full name: Albert Einstein
# 	Location: Princeton
#
# Username: mcurie
# 	Full name: Marie Curie
# 	Location: Paris
